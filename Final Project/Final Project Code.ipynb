# %%
import pandas

# %%
data = pandas.read_csv("housingPrices.csv")

# %%
data.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName     2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County  184529.317771
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  223663.797270
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County  100633.849158
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County  113818.556377
# 4          San Antonio-New Braunfels, TX        Bexar County   97963.402799
#
#       2000-02-29  ...     2022-10-31     2022-11-30     2022-12-31  \
# ...

# %%
len(data["RegionName"])
# Out:
# 22211

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22211 entries, 0 to 22210
# Columns: 291 entries, RegionID to 2023-07-31
# dtypes: float64(283), int64(2), object(6)
# memory usage: 49.3+ MB

# %%
dataSet = pd.DataFrame()

# %%
for i in range(data):
    if data["RegionName"] == Colorado
