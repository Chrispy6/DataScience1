# %%
pirates = [
    {
        "name": "Blackbeard",
        "sex": "Male",
        "age_at_death": 40,
        "height_in_feet": 6.4,
        "skull_and_cross_bones": False
    },
    {
        "name": "Anne Bonny",
        "sex": "Female",
        "age_at_death": 24,
        "height_in_feet": 5.6,
        "skull_and_cross_bones": True
    },
    {
        "name": "Calico Jack",
        "sex": "Male",
        "age_at_death": 37,
        "height_in_feet": 5.6,
        "skull_and_cross_bones": True
    },
    {
        "name": "Cheung Po Tsai",
        "sex": "Male",
        "age_at_death": 39,
        "height_in_feet": 5.3,
        "skull_and_cross_bones": False
    },
    {
        "name": "Grace O'Malley",
        "sex": "Female",
        "age_at_death": 73,
        "height_in_feet": 5.0,
        "skull_and_cross_bones": False
    },
    {
        "name": "Mary Read",
        "sex": "Female",
        "age_at_death": 36,
        "height_in_feet": 5.1,
        "skull_and_cross_bones": True
    },
    {
        "name": "Sayyida al Hurra",
        "sex": "Female",
        "age_at_death": 75,
        "height_in_feet": "unknown",
        "skull_and_cross_bones": False
    },
    {
        "name": "Ching Shih",
        "sex": "Female",
        "age_at_death": 69,
        "height_in_feet": 5.3,
        "skull_and_cross_bones": False
    },
    {
        "name": "Sir Francis Drake",
        "sex": "Male",
        "age_at_death": 56,
        "height_in_feet": 5.5,
        "skull_and_cross_bones": False
    },
    {
        "name": "Jean Lafitte",
        "sex": "Male",
        "age_at_death": 46,
        "height_in_feet": 6.6,
        "skull_and_cross_bones": False
    }
]

print(pirates[0]["name"])
print(pirates[0]["sex"])
print(pirates[0]["age_at_death"])
print(pirates[0]["skull_and_cross_bones"])
print("")

i = 9
while i >= 0:
    print(pirates[i]["skull_and_cross_bones"])
    i -= 1
print("")

x = 0
while x <= 9:
    print(pirates[x]["name"])
    print(pirates[x]["age_at_death"])
    print(pirates[x]["skull_and_cross_bones"])
    x += 1
# Out:
# Blackbeard
# Male
# 40
# False
#
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
#
# Blackbeard
# 40
# False
# Anne Bonny
# 24
# True
# Calico Jack
# 37
# True
# Cheung Po Tsai
# 39
# False
# Grace O'Malley
# 73
# False
# Mary Read
# 36
# True
# Sayyida al Hurra
# 75
# False
# Ching Shih
# 69
# False
# Sir Francis Drake
# 56
# False
# Jean Lafitte
# 46
# False
