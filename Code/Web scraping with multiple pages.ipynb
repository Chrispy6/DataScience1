# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.dictionary.com/list/a/1"

# %%
for i in range(1,10): 
    req = requests.get(URL + str(i) + '/') 
    soup = BeautifulSoup(req.text, 'html.parser') 
  
    titles = soup.find_all('div',attrs={'class','paragraph'})

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <base href="/"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-react-helmet="true">Browse Dictionary: Words Starting With A (Page 19) | Dictionary.com</title>
# ...

# %%
soup.find_all('a')
# Out:
# [<a aria-selected="true" class="Cw6IuvTLU7Ndrt26K9Bg" data-analytics="aa-track" data-linkmodule="site-navigation" data-linkmodule_position="1" data-linkname="dictionary.com" data-linktype="cta" data-linkurl="http://www.dictionary.com:80" data-location="header" data-type="sites-menu" href="http://www.dictionary.com:80" id="dictionary-tab" role="tab"><div class="elu13lxtzrRO8E8WYUVn"><svg fill="none" viewbox="0 0 256 35" xmlns="http://www.w3.org/2000/svg"><path d="M15.736.123.429 0A.424.424 0 0 0 0 .413v26.346a.467.467 0 0 0 .234.395l11.467 6.648a.378.378 0 0 0 .514-.13.38.38 0 0 0 .053-.195V8.852a.466.466 0 0 0-.248-.413L5.932 5.114a.244.244 0 0 1-.119-.297.244.244 0 0 1 .279-.158L17.1 6.539a.437.437 0 0 1 .355.426v22.171a.433.433 0 0 0 .436.434h.05c8.154-.91 13.71-6.62 13.828-14.54C31.88 6.171 25.288.247 15.736.123Z" fill="#0049D7"></path><path d="M62.713 15.658c0-6.076-4.51-10.16-11.222-10.16H44.8v20.454h6.69c6.606-.018 11.223-4.246 11.223-10.294Zm-13.867 6.658V9.113h2.623c4.369 0 7
# ...
